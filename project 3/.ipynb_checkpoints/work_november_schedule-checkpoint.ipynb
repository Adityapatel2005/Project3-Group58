# %%
# asked chat gpt why the example code was not working and then it told me to add the html_contet and three quotes 
html_content = """
<html>
<head>
    <title>Work Schedule for November 2024</title>
    <style>
        table {
            border-collapse: collapse;
            width: 100%;
            margin: 20px 0;  /* Fixed margin syntax */
        }
        th, td {
            border: 1px solid black;  /* Fixed border syntax */
            padding: 10px;  /* Fixed padding syntax */
            text-align: center;
        }
        th {
            background-color: #f2f2f2;
        }
        td {
            height: 100px;  /* Fixed height syntax */
            vertical-align: top;
        }
    </style>
</head>
<body>
    <h1>Work Schedule for November 2024</h1>
    <table>
        <tr>
            <th>Mon</th>
            <th>Tue</th>
            <th>Wed</th>
            <th>Thu</th>
            <th>Fri</th>
            <th>Sat</th>
            <th>Sun</th>
        </tr>
        <tr>
            <td></td>
            <td>1<br><b>AM:</b> David<br><b>PM:</b> Frank</td>
            <td>2<br><b>AM:</b> Frank<br><b>PM:</b> David</td>
            <td>3<br><b>AM:</b> David<br><b>PM:</b> David</td>
            <td>4<br><b>AM:</b> Eve<br><b>PM:</b> Charlie</td>
            <td>5<br><b>AM:</b> Charlie<br><b>PM:</b> Frank</td>
            <td>6<br><b>AM:</b> Eve<br><b>PM:</b> Frank</td>
        </tr>
        <tr>
            <td>7<br><b>AM:</b> Alice<br><b>PM:</b> Bob</td>
            <td>8<br><b>AM:</b> Alice<br><b>PM:</b> Grace</td>
            <td>9<br><b>AM:</b> Charlie<br><b>PM:</b> Bob</td>
            <td>10<br><b>AM:</b> Eve<br><b>PM:</b> Grace</td>
            <td>11<br><b>AM:</b> Grace<br><b>PM:</b> Alice</td>
            <td>12<br><b>AM:</b> Bob<br><b>PM:</b> Grace</td>
            <td>13<br><b>AM:</b> Charlie<br><b>PM:</b> Alice</td>
        </tr>
        <tr>
            <td>14<br><b>AM:</b> Alice<br><b>PM:</b> Frank</td>
            <td>15<br><b>AM:</b> Charlie<br><b>PM:</b> Charlie</td>
            <td>16<br><b>AM:</b> Grace<br><b>PM:</b> Charlie</td>
            <td>17<br><b>AM:</b> Charlie<br><b>PM:</b> David</td>
            <td>18<br><b>AM:</b> David<br><b>PM:</b> Frank</td>
            <td>19<br><b>AM:</b> Frank<br><b>PM:</b> Alice</td>
            <td>20<br><b>AM:</b> Grace<br><b>PM:</b> Bob</td>
        </tr>
        <tr>
            <td>21<br><b>AM:</b> Alice<br><b>PM:</b> Grace</td>
            <td>22<br><b>AM:</b> Alice<br><b>PM:</b> Bob</td>
            <td>23<br><b>AM:</b> Eve<br><b>PM:</b> Alice</td>
            <td>24<br><b>AM:</b> Eve<br><b>PM:</b> Charlie</td>
            <td>25<br><b>AM:</b> Frank<br><b>PM:</b> David</td>
            <td>26<br><b>AM:</b> Eve<br><b>PM:</b> Bob</td>
            <td>27<br><b>AM:</b> Eve<br><b>PM:</b> Alice</td>
        </tr>
        <tr>
            <td>28<br><b>AM:</b> Charlie<br><b>PM:</b> Bob</td>
            <td>29<br><b>AM:</b> Alice<br><b>PM:</b> Eve</td>
            <td>30<br><b>AM:</b> Bob<br><b>PM:</b> Grace</td>
            <td>31<br><b>AM:</b> Grace<br><b>PM:</b> Eve</td>
            <td></td><td></td><td></td>
        </tr>
    </table>
</body>
</html>
"""

# Write to a file
with open("schedule.html", "w") as file:
    file.write(html_content)

print("HTML work schedule generated successfully!")
# Out:
# HTML work schedule generated successfully!
