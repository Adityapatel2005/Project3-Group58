# %% [markdown]
# ### INST326 OOP Project 03

# %% [markdown]
# Rename this notebook, replacing "_Assignment" with "_YourName"<br>
# Insert Signature Block Here
# ###Vatsala Pigilam, Aditya Patel, Jessica Arora
# > INST326 Section 0104
# > Group 58
# > Project 03
# > November 22
# #### Honor Pledge
# > I pledge that the work contained in this assignment is my own, and that I have complied with University and course policies on academic integrity, and AI use.
# #### Disclosures and Citations
# > Example: *ChatGPT, response to the prompt "explain how to write a function in python. give an example. Include a citation to chat gpt for the response. include the prompt in the citation." OpenAI, August 29, 2024.*

# %% [markdown]
# ### The Project
# Everyone will do the same project this time. This is a group project, so you must work in your assigned groups. Include the link to your group's GitHub repository (one link per group). Use comments in your code to document your solution. If you need to write comments to the grader, add a markdown cell immediately above your code solution and add your comments there. Be sure to read and follow all the requirements and the Notebook Instructions at the bottom of this notebook. Your grade may depend on it!

# %% [markdown]
# #### 1. A Scheduling Program
# >  My wife is responsible for scheduling caregivers for her 93 year-old mother. Currently she writes out the schedule on a monthly calendar and photocopies it for everyone. I want all of you to help me write a program to help her with scheduling. While this is a specific application, this program will be broadly useful and adaptable to any scheduling needs for small businesses, clubs, and more.

# %% [markdown]
# #### Requirements
# >  Care is required 12 hours per day, 7 days a week. There are two shifts each day: 7:00 AM - 1:00 PM, and 1:00 PM to 7:00 PM. There are a total of 8 caregivers. Some are family members and some are paid. Each caregiver has their own availability for shifts that is generally the same from month to month, but there are exceptions for work, vacations, and other responsibilities. Your program should do the following:
# > 1. Manage caregivers and their schedules. Attributes include: name, phone, email, pay rate, and hours.
# > 2. Each caregiver should have their own availability schedule where they can indicate their availability for each shift. Availability categories are 'preferred', 'available' (default), and 'unavailable'.
# > 3. Create a care schedule that covers AM and PM shifts and displays caregiver names on a calendar (see example). The schedule should accomodate caregivers' individual schedules and availability preferences. The python calendar module provides options for creating HTML calendars. Sample code for the HTML calendar is in the project folder.
# > 4. Paid caregivers are paid weekly at $20/hr. Your program should calculate weekly pay based on assigned hours. Provide a separate pay report that lists weekly (gross: hours x rate) amounts to each caregiver, along with weekly and monthly totals. The report can be a text document, or presented in GUI or HTML format.

# %% [markdown]
# #### Group Requirements
# >  1. Your submitted project should follow OOP principles like abstraction, encapsulation, inheritance, and polymorphism as appropriate. Your program should use classes.
# >  2. Select a group leader who will host the group's project repository on their GitHub.
# >  3. Create the group repository and add a main program document. See example.
# >  4. Create branches off the main program for each group member, and assign part of the program to each member.
# >  5. Each member should work on their branch.
# >  6. When each member is finished, merge the branches back into the main program. You may use 'merge' or 'pull requests', your choice.
# >  7. iterate and debug as necessary.

# %% [markdown]
# #### Working with HTML
# > Since this is a course on python, not HTML, you are not expected to know HTML. Therefore, you may copy applicable portions of the sample code or use AI to write the HTML portions of your application. Ypu should write the main python code yourself.

# %% [markdown]
# #### What you need to turn in
# >  This is a group project. There will be one submission per group. Your submission will be graded as a group.
# >  1. Include your group number and the names of all group members in the signature block at the top of this notebook.
# >  2. In the cell below, paste the link to your project repository. One link per group. The grader will review the activity and history provided by GitHub. To add a hyperlink to a Jupyter markdown cell, follow the instructions in the cell below.
# >  3. Below the GitHub Repository Link cell is a code cell. Copy and paste your final program code into this cell.

# %% [markdown]
# #### GitHub Repository Link
# > Example: [INST326_Fall2024/Projects/Project03](https://github.com/sdempwolf/INST326_Fall_2024/tree/main/Projects/Project03)
# >
# > Edit the link code below with your information, then run this cell. Test the link! It should take you to your GitHub project repository.
# > [external link text](http://url_here)

# %% [markdown]
# # Solution - enter your code solution below
# https://github.com/Adityapatel2005/Project3-Group58/tree/main

# %% [markdown]
# We would like to add a comment that there might be some mishaps with the avaibility schedule but would like to recieve as much partial credit as possible. The code does run so just adding this comment for partial credit purposes.

# %%
# first part 
import calendar 
class CaregiverInfo:
    
    availability_options = ["preferred", "available", "unavailable"]  # availability options
    
    def __init__(self, name, phone, email, pay_rate):
        self.name = name
        self.phone = phone
        self.email = email
        self.pay_rate = pay_rate
        self.hours = 0 # zero for now but can change later 
        self.availability = "available"  # to set the availbility for the schedule 
        self.availability_dictionary = self.create_default_schedule()
    
    def create_default_schedule(self):
        schedule = {}
        for day in range(1, 8):  
            schedule[day] = {
                "7:00AM - 1:00PM": "available",
                "1:00PM - 7:00PM": "available"
            }
        return schedule
    def update_schedule(self):
        schedule = self.availability_dictionary
        availability_options = ["preferred", "available", "unavailable"]  # availability options
    
        day_names = list(calendar.day_name)  #days 
        
        for day in range(1, 8):
            print(f"\nAvailability for {day_names[day - 1]}")
            
            # Get availability for the morning shift
            morning_shift = input("Morning shift (7:00AM - 1:00PM): Enter 'preferred', 'available', or 'NA' (default is 'available'): ").strip().lower()
            if morning_shift in availability_options:
                schedule[day]["7:00AM - 1:00PM"] = morning_shift
            
            # Get availability for the afternoon shift
            afternoon_shift = input("Afternoon shift (1:00PM - 7:00PM): Enter 'preferred', 'available', or 'NA' (default is 'available'): ").strip().lower()
            if afternoon_shift in availability_options:
                schedule[day]["1:00PM - 7:00PM"] = afternoon_shift
        
        self.availability_dictionary= schedule
    
    def caregiver_working(self):# for caregivers hours to increase by 6 if scheduled to
        self.hours += 6
    
people = [
    CaregiverInfo("Alice", "334-678-5690", "Alice03@gmail.com", 20),# 20 is the fixed pay for the non-family members 
    CaregiverInfo("Bob", "456-231-3498", "Bob28@gmail.com", 20),
    CaregiverInfo("Charlie", "458-372-8609", "charlie89@gmail.com", 20),
    CaregiverInfo("David", "567-780-3451", "David459@gmail.com", 20),
    CaregiverInfo("Eve", "348-548-9908", "Eve123@gmail.com", 0),  # family members do not get paid
    CaregiverInfo("Frank", "567-2112-6732", "Frank13@gmail.com", 0),  # family member
    CaregiverInfo("Grace", "789-903-0043", "Grace34897@gmail.com", 0),  # family member
    CaregiverInfo("Justin", "345-2287-8765", "justin34@gmail.com", 0)  # family member
]
# second part - we want to add a comment that there were some issues with the code of availability not translating as well with the fourth part/payroll and would like to recieve as much partial credit as possible
# Function to displays all caregivers and their schedules
def display_all_caregivers_schedules():
    "Displays the availability schedule for all caregivers."
    for caregiver in people:
        print(f"\nSchedule for {caregiver.name}:")
        day_names = list(calendar.day_name)
        for day, shifts in caregiver.availability_dictionary.items():
            print(f"{day_names[day - 1]}:")
            print(f"  Morning shift (7:00AM - 1:00PM): {shifts['7:00AM - 1:00PM']}")
            print(f"  Afternoon shift (1:00PM - 7:00PM): {shifts['1:00PM - 7:00PM']}")
# Allows caregivers to update their availability 
def update_specific_caregiver_schedule():
    "Allows a user to select a caregiver and update their schedule interactively. "
    print("\nAvailable caregivers:")
    for i, caregiver in enumerate(people, start=1):
        print(f"{i}. {caregiver.name}")
    try:
        choice = int(input("\nSelect a caregiver by number: "))
        if choice < 1 or choice > len(people):
            print("Invalid selection. Please try again.")
            return
        
        selected_caregiver = people[choice - 1]
        print(f"\nYou selected {selected_caregiver.name}.")
        selected_caregiver.update_schedule() # Allows the selected caregiver to change availability 
        print(f"\nUpdated schedule for {selected_caregiver.name}:") # Displays the update
        day_names = list(calendar.day_name)
        for day, shifts in selected_caregiver.availability_dictionary.items():
            print(f"{day_names[day - 1]}:")
            print(f"  Morning shift (7:00AM - 1:00PM): {shifts['7:00AM - 1:00PM']}")
            print(f"  Afternoon shift (1:00PM - 7:00PM): {shifts['1:00PM - 7:00PM']}")
    except ValueError:
        print("Invalid input. Please enter a number.")
    except IndexError:
        print("Invalid selection. Please try again.")

def main(): # Main menu that lets you manage different options
    while True:
        print("\nCaregiver Availability Management System")
        print("---------------------------------")
        print("1. Display all caregiver schedules")
        print("2. Update a specific caregiver's schedule")
        print("0. Exit")
        
        try:
            option = int(input("\nChoose an option (0-2): "))
            
            if option == 0:
                print("\nExiting the program. Goodbye!")
                break
            elif option == 1:
                display_all_caregivers_schedules()
            elif option == 2:
                update_specific_caregiver_schedule()
            else:
                print("Invalid option. Please choose between 0 and 2.")
        
        except ValueError:
            print("Invalid input. Please enter a number.")

if __name__ == "__main__": #Runs part of the program
    main()
# third part 
import calendar
from datetime import datetime

def generate_care_schedule(year, month):
    """Generates an HTML calendar displaying caregiver schedules for AM and PM shifts.
    :param year: The year for the calendar.
    :param month: The month for the calendar."""
   
    cal = calendar.HTMLCalendar(calendar.SUNDAY)  # Creates an HTML Calendar 
    day_names = list(calendar.day_name)  #(Monday, Tuesday,...)
    schedule = {day: {"AM": [], "PM": []} for day in range(1, 8)} # Createed a dictionary to show the schedule for each day
    
    for caregiver in people:   # Add caregivers to the schedule based on availability
        for day, shifts in caregiver.availability_dictionary.items():
            if shifts["7:00AM - 1:00PM"] in ["preferred", "available"]:
                schedule[day]["AM"].append(caregiver.name)
                caregiver.hours += 6
            if shifts["1:00PM - 7:00PM"] in ["preferred", "available"]:
                schedule[day]["PM"].append(caregiver.name)
                caregiver.hours += 6
    
    html_calendar = cal.formatmonth(year, month) # Generates the HTML calendar
    
    for day in range(1, 8):  # Days are numbered from 1 (Monday) to 7 (Sunday) # Adds caregiver schedules to each day in the calendar
        am_caregivers = ", ".join(schedule[day]["AM"]) if schedule[day]["AM"] else "No one available"
        pm_caregivers = ", ".join(schedule[day]["PM"]) if schedule[day]["PM"] else "No one available"
        
        # Replace placeholders with AM and PM caregiver names
        html_calendar = html_calendar.replace(
            f">{day}<",
            f"><b>{day}</b><br>AM: {am_caregivers}<br>PM: {pm_caregivers}<"
        )
    
    with open("care_schedule.html", "w") as file: # Saves the HTML calendar to a file
        file.write("<html><head><title>Care Schedule</title></head><body>")
        file.write(f"<h1>Care Schedule for {calendar.month_name[month]} {year}</h1>")
        file.write(html_calendar)
        file.write("</body></html>")
    print(f"Care schedule saved as 'care_schedule.html'. Open this file in a browser to view it.")
if __name__ == "__main__":
    current_year = datetime.now().year    # Gets the current year and month
    current_month = datetime.now().month
    generate_care_schedule(current_year, current_month) # Generates the schedule for the current month
#4th part 
#Calculates weekly and monthly pay for all caregivers.
def calculate_pay_report():
    weekly_report = {}
    total_weekly_pay = 0
    total_monthly_pay = 0

    for caregiver in people:
        if caregiver.pay_rate > 0:  # Only paid caregivers
            weekly_pay = caregiver.hours * caregiver.pay_rate
            monthly_pay = weekly_pay * 4  # Assuming 4 weeks in a month
            weekly_report[caregiver.name] = {"Weekly Pay": weekly_pay, "Monthly Pay": monthly_pay}
            total_weekly_pay += weekly_pay
            total_monthly_pay += monthly_pay
    
    # Write the report to an HTML file
    with open("caregiver_pay_report.html", "w") as file:
        file.write("<html><head><title>Caregiver Pay Report</title></head><body>")
        file.write("<h1>Caregiver Weekly and Monthly Pay Report</h1>")
        file.write("<hr>")

        file.write("<table border='1' style='width:50%; border-collapse:collapse;'>")
        file.write("<tr><th>Caregiver</th><th>Weekly Pay</th><th>Monthly Pay</th></tr>")
        for caregiver, pay_info in weekly_report.items():
            file.write(f"<tr><td>{caregiver}</td>")
            file.write(f"<td>${pay_info['Weekly Pay']:.2f}</td>")
            file.write(f"<td>${pay_info['Monthly Pay']:.2f}</td></tr>")
        file.write("</table>")
        
        file.write("<hr>")
        file.write(f"<p><strong>Total Weekly Pay for All Caregivers:</strong> ${total_weekly_pay:.2f}</p>")
        file.write(f"<p><strong>Total Monthly Pay for All Caregivers:</strong> ${total_monthly_pay:.2f}</p>")
        file.write("</body></html>")

    print("Pay report generated and saved as 'caregiver_pay_report.html'. Open this file in a browser to view it.")

#Calls the function to generate the pay report as an HTML file
if __name__ == "__main__":
    calculate_pay_report()

# %% [markdown]
# ### Notebook Instructions
# > Before turning in your notebook:
# > 1. Make sure you have renamed the notebook file as instructed
# > 2. Make sure you have included your signature block and that it is correct according to the instructions
# > 3. comment your code as necessary
# > 4. run all code cells and double check that they run correctly. If you can't get your code to run correctly and you want partial credit, add a note for the grader in a new markdown cell directly above your code solution.<br><br>
# Turn in your notebook by uploading it to ELMS<br>
# IF the exercises involve saved data files, put your notebook and the data file(s) in a zip folder and upload the zip folder to ELMS
